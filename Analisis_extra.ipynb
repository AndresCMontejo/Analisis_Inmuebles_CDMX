# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresCMontejo/Analisis_Inmuebles_CDMX/blob/main/Analisis_extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTANDO LA BASE DE DATOS**

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
#leer el enlace
pd.read_csv(url, sep=",")
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
#Almacenando el contenido en un DataFrame de Pandas
datos = pd.read_csv(url, sep=",")
#Visualización de las primeras 7 filas del DataFrame
datos.head(7)
# Out:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
#Visualización de las ultimas 7 filas del DataFrame
datos.tail(7)
# Out:
#       Nombre  Edad  Nota   Aprobado
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
#Verifica la cantidad de filas y columnas en este DataFrame.
datos.shape
# Out:
# (18, 4)

# %%
#Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.
#Columna Nombre
datos.columns
# Out:
# Index(['Nombre', 'Edad', 'Nota', 'Aprobado'], dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
v1 = datos[["Nombre", "Aprobado"]] #Objecto
v2 = datos["Edad"] #int64
v3 = datos["Nota"] #float64
print(v1, v2, v3)
# Out:
#       Nombre   Aprobado
# 0    Alberto       True
# 1        Ana      False
# 2     Camila      False
# 3      David      False
# 4      Brian       True
# 5      Bruna      False
# 6    Daniela       True
# 7     Carlos      False
# 8     Alicia      False
# 9     Victor      False
# 10    Danilo      False
# 11   Ignacio      False
# 12  Stephany       True
# 13    Miriam       True
# 14     Pablo      False
# 15    Milena       True
# 16     Lucas      False
# 17     Nadia  Verdadero 0     20
# 1     18
# 2     27
# 3     18
# 4     21
# 5     23
# 6     21
# 7     19
# 8     35
# 9     28
# 10    21
# 11    24
# 12    26
# 13    25
# 14    37
# 15    29
# 16    33
# 17    34
# Name: Edad, dtype: int64 0      7.5
# 1      NaN
# 2      2.5
# 3      5.0
# 4     10.0
# 5      NaN
# 6      7.0
# 7      6.0
# 8      5.6
# 9      NaN
# 10     NaN
# 11     4.5
# 12    10.0
# 13     9.0
# 14     NaN
# 15     7.0
# 16     NaN
# 17     8.0
# Name: Nota, dtype: float64

# %%
#Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.). Pista: busca el método "describe".
datos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %%
#Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.
datos.isnull()
datos.isnull().sum() #muestra que columna(s) contiene(n) datos nulos(Nan)
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
#rellenando con "0" los valores nulos
datos = datos.fillna(0)

# %%
#Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.
datos_remover = datos.drop(datos[datos["Nombre"] == "Alicia"].index)
datos_remover = datos_remover.drop(datos_remover[datos_remover["Nombre"] == "Carlos"].index)
datos = datos_remover
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
#Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.
datos["Aprobado"] = datos["Aprobado"].replace("Verdadero", "True")
filtro = datos["Aprobado"] == "True"
alumnos_aprobados = datos[filtro]

# %%
#Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".
alumnos_aprobados.to_csv('/content/drive/MyDrive/ETL/PANDAS/alumnos_aprobados.csv', index=False, sep=',')

# %%
"""
Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones
eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se
contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0. Consejo: busca el método replace.
"""
datos["Nota"] = datos["Nota"].replace(7.0, 8.0)
datos
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 1        Ana    18   0.0    False
# 2     Camila    27   2.5    False
# 3      David    18   5.0    False
# 4      Brian    21  10.0     True
# 5      Bruna    23   0.0    False
# 6    Daniela    21   8.0     True
# 9     Victor    28   0.0    False
# 10    Danilo    21   0.0    False
# 11   Ignacio    24   4.5    False
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 14     Pablo    37   0.0    False
# 15    Milena    29   8.0     True
# 16     Lucas    33   0.0    False
# 17     Nadia    34   8.0     True

# %%
"""
Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual.
Por lo tanto, crea una columna llamada "Puntos_extras"
que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.
"""
datos['Puntos_extras'] = datos['Nota'].apply(lambda x: x*0.4)
datos
# Out:
#       Nombre  Edad  Nota Aprobado  Puntos_extras
# 0    Alberto    20   7.5     True            3.0
# 1        Ana    18   0.0    False            0.0
# 2     Camila    27   2.5    False            1.0
# 3      David    18   5.0    False            2.0
# 4      Brian    21  10.0     True            4.0
# 5      Bruna    23   0.0    False            0.0
# 6    Daniela    21   8.0     True            3.2
# 9     Victor    28   0.0    False            0.0
# 10    Danilo    21   0.0    False            0.0
# 11   Ignacio    24   4.5    False            1.8
# 12  Stephany    26  10.0     True            4.0
# 13    Miriam    25   9.0     True            3.6
# 14     Pablo    37   0.0    False            0.0
# 15    Milena    29   8.0     True            3.2
# 16     Lucas    33   0.0    False            0.0
# 17     Nadia    34   8.0     True            3.2

# %%
"""
Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.
"""
datos['Notas_finales'] = datos['Nota'] + datos['Puntos_extras']
datos
# Out:
#       Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales
# 0    Alberto    20   7.5     True            3.0           10.5
# 1        Ana    18   0.0    False            0.0            0.0
# 2     Camila    27   2.5    False            1.0            3.5
# 3      David    18   5.0    False            2.0            7.0
# 4      Brian    21  10.0     True            4.0           14.0
# 5      Bruna    23   0.0    False            0.0            0.0
# 6    Daniela    21   8.0     True            3.2           11.2
# 9     Victor    28   0.0    False            0.0            0.0
# 10    Danilo    21   0.0    False            0.0            0.0
# 11   Ignacio    24   4.5    False            1.8            6.3
# 12  Stephany    26  10.0     True            4.0           14.0
# 13    Miriam    25   9.0     True            3.6           12.6
# 14     Pablo    37   0.0    False            0.0            0.0
# 15    Milena    29   8.0     True            3.2           11.2
# ...

# %%
"""
Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora.
En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:

True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).
"""
datos['Aprobado_final'] = datos['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)
datos
# Out:
#       Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5     True            3.0           10.5
# 1        Ana    18   0.0    False            0.0            0.0
# 2     Camila    27   2.5    False            1.0            3.5
# 3      David    18   5.0    False            2.0            7.0
# 4      Brian    21  10.0     True            4.0           14.0
# 5      Bruna    23   0.0    False            0.0            0.0
# 6    Daniela    21   8.0     True            3.2           11.2
# 9     Victor    28   0.0    False            0.0            0.0
# 10    Danilo    21   0.0    False            0.0            0.0
# 11   Ignacio    24   4.5    False            1.8            6.3
# 12  Stephany    26  10.0     True            4.0           14.0
# 13    Miriam    25   9.0     True            3.6           12.6
# 14     Pablo    37   0.0    False            0.0            0.0
# 15    Milena    29   8.0     True            3.2           11.2
# ...

# %%
#Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.
seleccion = (datos['Aprobado'] == "False") & (datos['Aprobado_final'] == True)
datos[seleccion]
# Out:
#   Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 3  David    18   5.0    False            2.0            7.0            True
